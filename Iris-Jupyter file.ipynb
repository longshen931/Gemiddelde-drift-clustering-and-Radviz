# %%
#Reference:https://stackoverflow.com/questions/12332975/installing-python-module-within-code
def install_and_import(package):
    import importlib
    try:
        importlib.import_module(package)
    except ImportError:
        import pip
        pip.main(['install', package])
    finally:
        globals()[package] = importlib.import_module(package)


install_and_import('plotly')
install_and_import('numpy')
install_and_import('pandas')
install_and_import('matplotlib')
install_and_import('sklearn')
# install_and_import('RadViz-Plotly')  this function doesn't work with the released packge

# !pip install RadViz-Plotly
# Out:
# Requirement already satisfied: RadViz-Plotly in c:\users\100775689\anaconda3\lib\site-packages (0.0.4)

# %% [markdown]
# ###  Iris Dataset
# ###  Labels :Iris Setosa, Iris Versicolour, andIris Virginica

# %%
from RadViz.main import RadViz3D
from RadViz.main import RadViz2D
import pandas as pd
import time

# %%
data= pd.read_csv('iris.csv')
y=data['Species']
X=data.drop(['Species'], axis=1)

# %%
BPs=10000
time_start = time.time()
RadViz3D(y,X,BPs)
print( 'RadViz3D done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# <div>
#
#
#             <div id="cda15d58-793f-4cc5-9dcb-fb584b5aae30" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cda15d58-793f-4cc5-9dcb-fb584b5aae30")) {
#                     Plotly.newPlot(
#                         'cda15d58-793f-4cc5-9dcb-fb584b5aae30',
#                         [{"hovertemplate": "label=Anchors' Names<br>x=%{x}<br>y=%{y}<br>z=%{z}<br>AnchorsLabel=%{text}<extra></extra>", "legendgroup": "Anchors' Names", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers+text", "name": "Anchors' Names", "scene": "scene", "showlegend": true, "text": ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"], "type": "scatter3d", "x": [0.239688, -0.868306, 0.929656, -0.343404], "y": [-0.616482, 0.428421, 0.270628, -0.565308], "z": [0.75, 0.25, -0.25, -0.75]}, {"hovertemplate": "label=Iris-setosa<br>x=%{x}<br>y=%{y}<br>z=%{z}<br>AnchorsLabel=%{text}<extra></extra>", "legendgroup": "Iris-setosa", "marker": {"color": "#00CC96", "symbol": "circle"}, "mode": "markers+text", "name": "Iris-setosa", "scene": "scene", "showlegend": true, "text": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type": "scatter3d", "x": [-0.4606615497047245, -0.3942385647298673, -0.532327206423553, -0.46929125369978864, -0.4982056473441667, -0.4077947601825843, -0.5528603350604491, -0.43733046810726367, -0.5275596755514703, -0.39343831442786065, -0.41860530099091653, -0.4540161718792494, -0.425885487915408, -0.7980273550488599, -0.4575506169419285, -0.4624165330584598, -0.47901994859467456, -0.45576775430323047, -0.35524521278089877, -0.4803976672171759, -0.32146805654027366, -0.4612177221304708, -0.7240486315789475, -0.34693516760152565, -0.3772442250192653, -0.31141667644305765, -0.40647202062338883, -0.4177033667136811, -0.422011283895131, -0.4337972929797192, -0.3840899485060394, -0.3617352920505678, -0.5133817057793344, -0.49087912311688303, -0.39343831442786065, -0.480957413634974, -0.4090347298387096, -0.39343831442786065, -0.5999979167032002, -0.41715158979540284, -0.5006490896075043, -0.24327856245325333, -0.6360438603415559, -0.41885604210087535, -0.3993384592201921, -0.41615915656229185, -0.46409127664064137, -0.5275140917431194, -0.43504173973762167, -0.4434942644766146], "y": [0.1312451021161418, 0.10184072782874602, 0.19316923118099694, 0.2160914809725159, 0.16540273781227258, 0.0837085939255617, 0.20760346632124355, 0.14313451444936212, 0.27004187729779383, 0.16420978805970132, 0.10039052786952926, 0.19438527005711181, 0.17844473338368588, 0.42225319543973944, 0.0647039808204582, 0.08816841054336617, 0.07375430602810638, 0.10217415208677201, 0.049648616924157195, 0.1404412357555739, 0.06680964729638762, 0.10413032886044594, 0.2661296842105264, 0.031410401839802544, 0.19861553711790395, 0.08297747831513257, 0.0865118007968127, 0.1128632898448518, 0.09608107415730333, 0.1983895413416536, 0.15488337158296248, 0.012573630597814363, 0.20143277933450082, 0.1338899064935065, 0.16420978805970132, 0.1038407178232956, 0.04993623991935478, 0.16420978805970132, 0.2823132073651905, 0.12049375953523624, 0.12011361120710927, -0.04462347419596133, 0.30194211005692584, 0.05103320946227588, 0.1239741371256357, 0.09074038041305799, 0.1687786617429838, 0.22752732721712546, 0.11828958802369874, 0.12652114059020036], "z": [0.2871555118110236, 0.2612130479102957, 0.23360655737704927, 0.18657505285412257, 0.2723138491389765, 0.22647471910112363, 0.15759930915371323, 0.26457953657901595, 0.12959558823529427, 0.3077114427860697, 0.31028075970272506, 0.22334783791134077, 0.30702416918429004, 0.2304560260586319, 0.36294619072988815, 0.2669341775879841, 0.2518491124260355, 0.243869370431502, 0.28862359550561806, 0.23720066061106523, 0.29936055642809073, 0.20066061106523528, 0.25, 0.1405093111958716, 0.19708451066015928, 0.2562402496099844, 0.17172486524490277, 0.2909026798307476, 0.302434456928839, 0.20101404056162253, 0.2188493324856961, 0.2367152346260982, 0.31830122591943966, 0.31701298701298697, 0.3077114427860697, 0.30013757260776525, 0.344758064516129, 0.3077114427860697, 0.150920648838229, 0.27904773932811316, 0.23790422117995558, -0.007 ...
# RadViz3D done! Time elapsed: 0.38259220123291016 seconds

# %%
BPs=1000
time_start = time.time()
RadViz2D(y,X,BPs)
print( 'RadViz2D done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# <div>
#
#
#             <div id="db246ae4-3e87-4fb2-b0ec-cf7bfcffbeea" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db246ae4-3e87-4fb2-b0ec-cf7bfcffbeea")) {
#                     Plotly.newPlot(
#                         'db246ae4-3e87-4fb2-b0ec-cf7bfcffbeea',
#                         [{"hovertemplate": "label=Anchors' Names<br>0=%{x}<br>1=%{y}<br>AnchorsLabel=%{text}<extra></extra>", "legendgroup": "Anchors' Names", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers+text", "name": "Anchors' Names", "orientation": "v", "showlegend": true, "text": ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"], "type": "scatter", "x": [1.0, 0.0, -1.0, -0.0], "xaxis": "x", "y": [0.0, 1.0, 0.0, -1.0], "yaxis": "y"}, {"hovertemplate": "label=Iris-setosa<br>0=%{x}<br>1=%{y}<br>AnchorsLabel=%{text}<extra></extra>", "legendgroup": "Iris-setosa", "marker": {"color": "#00CC96", "symbol": "circle"}, "mode": "markers+text", "name": "Iris-setosa", "orientation": "v", "showlegend": true, "text": ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], "type":